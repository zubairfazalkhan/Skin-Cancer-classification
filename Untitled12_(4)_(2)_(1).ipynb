# %%
import os
import json
import random
import cv2
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
os.environ['KAGGLE_DIR'] = '/content'

# %%
# Define your Kaggle API credentials as a dictionary
kaggle_creds = {
    "username": "syntaxxerror",
    "key": "827a2cca47b20a4af7a3dab566c40185"
}

# Save the credentials to a JSON file
with open('/root/.kaggle/kaggle.json', 'w') as creds_file:
    json.dump(kaggle_creds, creds_file)

# Set appropriate permissions to the file
os.chmod('/root/.kaggle/kaggle.json', 600)

# %%
# !kaggle datasets download -d nodoubttome/skin-cancer9-classesisic
# Out:
# ...
#  99% 774M/786M [00:09<00:00, 140MB/s]
# 100% 786M/786M [00:09<00:00, 86.5MB/s]

# %%
# !unzip skin-cancer9-classesisic.zip
# Out:
# Archive:  skin-cancer9-classesisic.zip
#   inflating: Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0010512.jpg
#   inflating: Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0010889.jpg
#   inflating: Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0024468.jpg
#   inflating: Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0024470.jpg
#   inflating: Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0024511.jpg
#   inflating: Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0024646.jpg
#   inflating: Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0024654.jpg
#   inflating: Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0024707.jpg
# ...

# %%
# Specify the dataset folder and class labels
dataset_folder = '/content/Skin cancer ISIC The International Skin Imaging Collaboration/'

# Define the paths to the train and test data for each class
train_path = os.path.join(dataset_folder, 'Train/{0}/')
test_path = os.path.join(dataset_folder, 'Test/{0}/')

# %%
# Define the path to the Train folder
train_folder = os.path.join(dataset_folder, 'Train')

# List the class labels (subdirectories) in the Train folder
class_labels = os.listdir(train_folder)

# Print the class labels
print(class_labels)
num_cls = len(class_labels)
print(num_cls)
# Out:
# ['dermatofibroma', 'pigmented benign keratosis', 'nevus', 'seborrheic keratosis', 'melanoma', 'vascular lesion', 'squamous cell carcinoma', 'basal cell carcinoma', 'actinic keratosis']
# 9

# %%
import os
import matplotlib.pyplot as plt

# Define the path to the Train folder
train_folder = os.path.join(dataset_folder, 'Train')

# List the class labels (subdirectories) in the Train folder
class_labels = os.listdir(train_folder)

# Count the number of classes
num_cls = len(class_labels)

# Create a pie chart to visualize the class distribution
plt.figure(figsize=(8, 8))
plt.pie([1] * num_cls, labels=class_labels, autopct='%1.1f%%', startangle=140)
plt.title('Class Distribution')
plt.show()

# %%
# Define the number of sample images to display
num_samples = min(9, num_cls)  # Display up to 9 samples

plt.figure(figsize=(12, 8))
for i in range(num_samples):
    label = class_labels[i]
    img_files = os.listdir(train_path.format(label))
    img_file = random.choice(img_files)
    img_path = os.path.join(train_path.format(label), img_file)
    img = cv2.imread(img_path)
    plt.subplot(3, 3, i + 1)
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.title(label)
    plt.axis('off')
plt.show()

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input

# ... the rest of your code ...

# Define the ImageDataGenerator with augmentation and preprocessing
img_data_gen = ImageDataGenerator(
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    preprocessing_function=preprocess_input
)

# ... the rest of your code ...

import matplotlib.pyplot as plt
import os

# Number of samples/images per iteration
BATCH_SIZE = 32

# Input image size
IMG_SIZE = (224, 224)

# Count of epochs
EPOCHS = 10

# Define the ImageDataGenerator with augmentation and preprocessing
img_data_gen = ImageDataGenerator(
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    preprocessing_function=preprocess_input)
 # Assuming preprocess_input is defined

# Create data generators for training and validation
X_train_gen = img_data_gen.flow_from_directory(
    os.path.join(dataset_folder, 'Train'),  # Corrected path
    target_size=IMG_SIZE,
    color_mode='rgb',
    class_mode='categorical',
    batch_size=BATCH_SIZE,
    seed=1
)

X_val_gen = img_data_gen.flow_from_directory(
    os.path.join(dataset_folder, 'Test'),  # Corrected path
    target_size=IMG_SIZE,
    color_mode='rgb',
    class_mode='categorical',
    batch_size=BATCH_SIZE,
    seed=1
)

# Plot some augmented images
fig, ax = plt.subplots(nrows=3, ncols=3, figsize=(12, 12))

for i, a in enumerate(ax.flat):
    img, label = X_train_gen.next()
    a.imshow(img[0])
    a.set_title(label[0])

plt.tight_layout()
plt.show()
# Out:
# Found 2239 images belonging to 9 classes.
# Found 118 images belonging to 9 classes.
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /usr/local/lib/python3.10/dist-packages/matplotlib/text.py:1279: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Data Preprocessing and Augmentation
datagen = ImageDataGenerator(
    rescale=1.0 / 255.0,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2
)

train_generator = datagen.flow_from_directory(
    train_folder,
    target_size=(150, 150),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

validation_generator = datagen.flow_from_directory(
    train_folder,
    target_size=(150, 150),
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)

# Define the CNN model
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(num_cls, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(train_generator, epochs=10, validation_data=validation_generator)
# Out:
# Found 1795 images belonging to 9 classes.
# Found 444 images belonging to 9 classes.
# Epoch 1/10
# 57/57 [==============================] - 107s 2s/step - loss: 1.9130 - accuracy: 0.2992 - val_loss: 1.8260 - val_accuracy: 0.3221
# Epoch 2/10
# 57/57 [==============================] - 111s 2s/step - loss: 1.7027 - accuracy: 0.3922 - val_loss: 1.9046 - val_accuracy: 0.4257
# Epoch 3/10
# 57/57 [==============================] - 111s 2s/step - loss: 1.4525 - accuracy: 0.4969 - val_loss: 1.7146 - val_accuracy: 0.4550
# Epoch 4/10
# 57/57 [==============================] - 108s 2s/step - loss: 1.3880 - accuracy: 0.5187 - val_loss: 1.9120 - val_accuracy: 0.3761
# Epoch 5/10
# 57/57 [==============================] - 111s 2s/step - loss: 1.3258 - accuracy: 0.5270 - val_loss: 1.7405 - val_accuracy: 0.4347
# Epoch 6/10
# 57/57 [==============================] - 112s 2s/step - loss: 1.3027 - accuracy: 0.5487 - val_loss: 2.0991 - val_accuracy: 0.4032
# Epoch 7/10
# ...

# %%
import matplotlib.pyplot as plt

# Evaluate the model on the validation data
validation_results = model.evaluate(validation_generator)

# Print the evaluation results
print("Validation Loss:", validation_results[0])
print("Validation Accuracy:", validation_results[1])

# Plot the training and validation accuracy over epochs
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

# Plot the training and validation loss over epochs
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# 14/14 [==============================] - 12s 829ms/step - loss: 1.6865 - accuracy: 0.4505
# Validation Loss: 1.686543345451355
# Validation Accuracy: 0.45045045018196106

# %% [markdown]
# **Hyperparameter tuning**

# %%
# Define a custom learning rate
custom_learning_rate = 0.001

# Compile the model with the custom learning rate
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=custom_learning_rate),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model with the adjusted learning rate
lr_history = model.fit(train_generator, epochs=10, validation_data=validation_generator)
# Out:
# Epoch 1/10
# 57/57 [==============================] - 105s 2s/step - loss: 1.2408 - accuracy: 0.5705 - val_loss: 2.1603 - val_accuracy: 0.4662
# Epoch 2/10
# 57/57 [==============================] - 104s 2s/step - loss: 1.1220 - accuracy: 0.6006 - val_loss: 2.0388 - val_accuracy: 0.4550
# Epoch 3/10
# 57/57 [==============================] - 120s 2s/step - loss: 1.0779 - accuracy: 0.6089 - val_loss: 1.9229 - val_accuracy: 0.4144
# Epoch 4/10
# 57/57 [==============================] - 113s 2s/step - loss: 1.1156 - accuracy: 0.6033 - val_loss: 1.9199 - val_accuracy: 0.4505
# Epoch 5/10
# 57/57 [==============================] - 112s 2s/step - loss: 1.0221 - accuracy: 0.6251 - val_loss: 1.9694 - val_accuracy: 0.4730
# Epoch 6/10
# 57/57 [==============================] - 111s 2s/step - loss: 1.0003 - accuracy: 0.6351 - val_loss: 1.9409 - val_accuracy: 0.4662
# Epoch 7/10
# ...

# %%
# Define a custom batch size
custom_batch_size = 32

# Create a new data generator with the custom batch size
custom_datagen = ImageDataGenerator(
    rescale=1.0 / 255.0,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2
)

custom_train_generator = custom_datagen.flow_from_directory(
    train_folder,
    target_size=(150, 150),
    batch_size=custom_batch_size,
    class_mode='categorical',
    subset='training'
)

# Train the model with the adjusted batch size
batch_size_history = model.fit(custom_train_generator, epochs=10, validation_data=validation_generator)
# Out:
# Found 1795 images belonging to 9 classes.
# Epoch 1/10
# 57/57 [==============================] - 112s 2s/step - loss: 0.9013 - accuracy: 0.6752 - val_loss: 2.6310 - val_accuracy: 0.4414
# Epoch 2/10
# 57/57 [==============================] - 111s 2s/step - loss: 0.8592 - accuracy: 0.6930 - val_loss: 2.2654 - val_accuracy: 0.4707
# Epoch 3/10
# 57/57 [==============================] - 111s 2s/step - loss: 0.8471 - accuracy: 0.6930 - val_loss: 2.5107 - val_accuracy: 0.4955
# Epoch 4/10
# 57/57 [==============================] - 111s 2s/step - loss: 0.8982 - accuracy: 0.6724 - val_loss: 2.1797 - val_accuracy: 0.4482
# Epoch 5/10
# 57/57 [==============================] - 111s 2s/step - loss: 0.8050 - accuracy: 0.7092 - val_loss: 2.4346 - val_accuracy: 0.4347
# Epoch 6/10
# 57/57 [==============================] - 111s 2s/step - loss: 0.8561 - accuracy: 0.6914 - val_loss: 2.2039 - val_accuracy: 0.4572
# Epoch 7/10
# ...

# %%
# Train the model for a different number of epochs (e.g., 20)
epochs_history = model.fit(train_generator, epochs=20, validation_data=validation_generator)
# Out:
# Epoch 1/20
# 57/57 [==============================] - 111s 2s/step - loss: 0.7663 - accuracy: 0.7203 - val_loss: 2.1780 - val_accuracy: 0.5000
# Epoch 2/20
# 57/57 [==============================] - 110s 2s/step - loss: 0.7141 - accuracy: 0.7343 - val_loss: 2.4896 - val_accuracy: 0.4752
# Epoch 3/20
# 57/57 [==============================] - 110s 2s/step - loss: 0.6670 - accuracy: 0.7599 - val_loss: 2.9488 - val_accuracy: 0.4707
# Epoch 4/20
# 57/57 [==============================] - 110s 2s/step - loss: 0.6212 - accuracy: 0.7727 - val_loss: 2.4268 - val_accuracy: 0.4707
# Epoch 5/20
# ...
# 57/57 [==============================] - 102s 2s/step - loss: 0.6499 - accuracy: 0.7560 - val_loss: 3.1535 - val_accuracy: 0.4595
# Epoch 7/20
# 57/57 [==============================] - 111s 2s/step - loss: 0.6541 - accuracy: 0.7465 - val_loss: 2.7537 - val_accuracy: 0.4977
# Epoch 8/20
# ...

# %%
# Evaluate the model with custom learning rate
lr_evaluation = model.evaluate(validation_generator)

# Print the evaluation results
print("Custom Learning Rate - Validation Loss:", lr_evaluation[0])
print("Custom Learning Rate - Validation Accuracy:", lr_evaluation[1])

# Plot the training and validation accuracy over epochs
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(lr_history.history['accuracy'], label='Training Accuracy')
plt.plot(lr_history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Custom Learning Rate - Training and Validation Accuracy')
plt.legend()

# Plot the training and validation loss over epochs
plt.subplot(1, 2, 2)
plt.plot(lr_history.history['loss'], label='Training Loss')
plt.plot(lr_history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Custom Learning Rate - Training and Validation Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# 14/14 [==============================] - 12s 828ms/step - loss: 3.7371 - accuracy: 0.4595
# Custom Learning Rate - Validation Loss: 3.737118721008301
# Custom Learning Rate - Validation Accuracy: 0.45945945382118225

# %%
# Evaluate the model with custom batch size
batch_size_evaluation = model.evaluate(validation_generator)

# Print the evaluation results
print("Custom Batch Size - Validation Loss:", batch_size_evaluation[0])
print("Custom Batch Size - Validation Accuracy:", batch_size_evaluation[1])

# Plot the training and validation accuracy over epochs
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(batch_size_history.history['accuracy'], label='Training Accuracy')
plt.plot(batch_size_history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Custom Batch Size - Training and Validation Accuracy')
plt.legend()

# Plot the training and validation loss over epochs
plt.subplot(1, 2, 2)
plt.plot(batch_size_history.history['loss'], label='Training Loss')
plt.plot(batch_size_history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Custom Batch Size - Training and Validation Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# 14/14 [==============================] - 12s 823ms/step - loss: 4.0461 - accuracy: 0.4775
# Custom Batch Size - Validation Loss: 4.046053409576416
# Custom Batch Size - Validation Accuracy: 0.477477490901947

# %%
# Evaluate the model with different epochs
epochs_evaluation = model.evaluate(validation_generator)

# Print the evaluation results
print("Different Epochs - Validation Loss:", epochs_evaluation[0])
print("Different Epochs - Validation Accuracy:", epochs_evaluation[1])

# Plot the training and validation accuracy over epochs
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(epochs_history.history['accuracy'], label='Training Accuracy')
plt.plot(epochs_history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Different Epochs - Training and Validation Accuracy')
plt.legend()

# Plot the training and validation loss over epochs
plt.subplot(1, 2, 2)
plt.plot(epochs_history.history['loss'], label='Training Loss')
plt.plot(epochs_history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Different Epochs - Training and Validation Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# 14/14 [==============================] - 12s 836ms/step - loss: 4.1612 - accuracy: 0.4662
# Different Epochs - Validation Loss: 4.161222457885742
# Different Epochs - Validation Accuracy: 0.46621620655059814

# %%
# Specify the path to the test data
test_data_folder = os.path.join(dataset_folder, 'Test')

# Make predictions on the test data
test_generator = datagen.flow_from_directory(
    test_data_folder,
    target_size=(150, 150),
    batch_size=1,  # Use batch size 1 for predicting each image individually
    class_mode='categorical',
    shuffle=False  # Ensure the order of predictions matches the order of true labels
)

predictions = model.predict(test_generator)
# Out:
# Found 118 images belonging to 9 classes.
# 118/118 [==============================] - 9s 72ms/step

# %%
from sklearn.metrics import confusion_matrix, classification_report

true_labels = test_generator.classes
predicted_labels = predictions.argmax(axis=1)  # Convert predicted probabilities to class labels

# Calculate the confusion matrix
confusion = confusion_matrix(true_labels, predicted_labels)

# Print the confusion matrix
print("Confusion Matrix:")
print(confusion)

# You can also print a classification report for more detailed metrics
report = classification_report(true_labels, predicted_labels, target_names=class_labels)
print("Classification Report:")
print(report)
# Out:
# Confusion Matrix:
# [[ 0  1  0  0 14  0  0  1  0]
#  [ 0  5  5  0  1  2  0  3  0]
#  [ 0  3  4  2  3  4  0  0  0]
#  [ 0  1  0  1 10  4  0  0  0]
#  [ 0  0  0  0 15  1  0  0  0]
#  [ 0  2  0  1  0 11  0  2  0]
#  [ 0  0  0  3  0  0  0  0  0]
#  [ 1  2  0  2  4  2  0  4  1]
#  [ 0  1  0  0  0  0  0  0  2]]
# Classification Report:
#                             precision    recall  f1-score   support
#
#             dermatofibroma       0.00      0.00      0.00        16
# pigmented benign keratosis       0.33      0.31      0.32        16
#                      nevus       0.44      0.25      0.32        16
#       seborrheic keratosis       0.11      0.06      0.08        16
#                   melanoma       0.32      0.94      0.48        16
#            vascular lesion       0.46      0.69      0.55        16
#    squamous cell carcinoma       0.00      0.00      0.00         3
#       basal cell carcinoma       0.40      0.25      0.31        16
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Calculate the confusion matrix
confusion = confusion_matrix(true_labels, predicted_labels)

# Plot the confusion matrix as a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(confusion, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
